# %%
TICKERS = [
    'AAPL',
    'MSFT',
    'GOOGL',
    'AMZN',
    'NVDA',
    'META',
    'TSLA'
]

# %%
import yfinance as yf
df = yf.download(tickers=TICKERS, start='2000-01-01', end=None)

df
# Out:
# /var/folders/89/hqh4vvhn24q2xc8ph93krqz80000gn/T/ipykernel_45562/1107376388.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(tickers=TICKERS, start='2000-01-01', end=None)
# [*********************100%***********************]  7 of 7 completed
# Price            Close                                                  \
# Ticker            AAPL        AMZN       GOOGL        META        MSFT
# Date
# 2000-01-03    0.840094    4.468750         NaN         NaN   35.668083
# 2000-01-04    0.769266    4.096875         NaN         NaN   34.463203
# ...                ...         ...         ...         ...         ...
# 2025-10-08  258.059998  225.220001  244.619995  717.840027  524.849976
# 2025-10-09         NaN  222.130005         NaN  719.349976  521.809998
#
# Price                                     High                          ...  \
# Ticker            NVDA        TSLA        AAPL        AMZN       GOOGL  ...
# ...

# %%
df.to_parquet('../YFINANCE/magnificent7_2000-today.parquet')
